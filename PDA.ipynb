# %%
import numpy as np

# %%
points = np.arange(-5, 5, 0.01) # 1000 equally spaced points
xs, ys = np.meshgrid(points, points)
import matplotlib.pyplot as plt
z = np.sqrt(xs ** 2 + ys ** 2)
plt.imshow(z, cmap=plt.cm.gray); plt.colorbar()
plt.title("Image plot of $\sqrt{x^2 + y^2}$ for a grid of values")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in show(close)
#     100     try:
#     101         for figure_manager in Gcf.get_all_fig_managers():
# --> 102             send_figure(figure_manager.canvas.figure)
#     103     finally:
#     104         show._to_draw = []
#
# /usr/lib/python2.7/dist-packages/IPython/zmq/pylab/backend_inline.pyc in send_figure(fig)
#     209     """
#     210     fmt = InlineBackend.instance().figure_format
# --> 211     data = print_figure(fig, fmt)
#     212     # print_figure will return None if there's nothing to draw:
#     213     if data is None:
#
# /usr/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt)
#     102     try:
#     103         bytes_io = BytesIO()
# --> 104         fig.canvas.print_figure(bytes_io, format=fmt, bbox_inches='tight')
#     105         data = bytes_io.getvalue()
#     106     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2050                     orientation=orientation,
#    2051                     dryrun=True,
# -> 2052                     **kwargs)
#    2053                 renderer = self.figure._cachedRenderer
#    2054                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     489
#     490     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 491         FigureCanvasAgg.draw(self)
#     492         renderer = self.get_renderer()
#     493         original_dpi = renderer.dpi
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     437
#     438         try:
# --> 439             self.figure.draw(self.renderer)
#     440         finally:
#     441             RendererAgg.lock.release()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      52     def draw_wrapper(artist, renderer, *args, **kwargs):
#      53         before(artist, renderer)
# ---> 54         draw(artist, renderer, *args, **kwargs)
#      55         after(artist, renderer)
#      56
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.pyc in draw(self, renderer)
#     997         dsu.sort(key=itemgetter(0))
#     998         for zorder, a, func, args in dsu:
# --> 999             func(*args)
#    1000
#    1001         renderer.close_group('figure')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      52     def draw_wrapper(artist, renderer, *args, **kwargs):
#      53         before(artist, renderer)
# ---> 54         draw(artist, renderer, *args, **kwargs)
#      55         after(artist, renderer)
#      56
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes.pyc in draw(self, renderer, inframe)
#    2084
#    2085         for zorder, a in dsu:
# -> 2086             a.draw(renderer)
#    2087
#    2088         renderer.close_group('axes')
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      52     def draw_wrapper(artist, renderer, *args, **kwargs):
#      53         before(artist, renderer)
# ---> 54         draw(artist, renderer, *args, **kwargs)
#      55         after(artist, renderer)
#      56
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/text.pyc in draw(self, renderer)
#     529         renderer.open_group('text', self.get_gid())
#     530
# --> 531         bbox, info = self._get_layout(renderer)
#     532         trans = self.get_transform()
#     533
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/text.pyc in _get_layout(self, renderer)
#     311                 w, h, d = get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backends/backend_agg.pyc in get_text_width_height_descent(self, s, prop, ismath)
#     202         if ismath:
#     203             ox, oy, width, height, descent, fonts, used_characters = \
# --> 204                 self.mathtext_parser.parse(s, self.dpi, prop)
#     205             return width, height, descent
#     206
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, dpi, prop)
#    3008             self.__class__._parser = Parser()
#    3009
# -> 3010         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3011         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3012         result = font_output.get_results(box)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in parse(self, s, fonts_object, fontsize, dpi)
#    2336         self._em_width_cache = {}
#    2337         try:
# -> 2338             result = self._expression.parseString(s)
#    2339         except ParseBaseException as err:
#    2340             raise ValueError("\n".join([
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in parseString(self, instring, parseAll)
#    1087             instring = instring.expandtabs()
#    1088         try:
# -> 1089             loc, tokens = self._parse( instring, 0 )
#    1090             if parseAll:
#    1091                 #loc = self.preParse( instring, loc )
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1018         else:
#    1019             try:
# -> 1020                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#    1021                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#    1022                 return value
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     960             if self.mayIndexError or loc >= len(instring):
#     961                 try:
# --> 962                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     963                 except IndexError:
#     964                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in parseImpl(self, instring, loc, doActions)
#    2679     def parseImpl( self, instring, loc, doActions=True ):
#    2680         if self.expr is not None:
# -> 2681             return self.expr._parse( instring, loc, doActions, callPreParse=False )
#    2682         else:
#    2683             raise ParseException("",loc,self.errmsg,self)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1018         else:
#    1019             try:
# -> 1020                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#    1021                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#    1022                 return value
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     960             if self.mayIndexError or loc >= len(instring):
#     961                 try:
# --> 962                     loc,tokens = self.parseImpl( instring, preloc, doActions )
#     963                 except IndexError:
#     964                     raise ParseException( instring, len(instring), self.errmsg, self )
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in parseImpl(self, instring, loc, doActions)
#    2407         # pass False as last arg to _parse for first element, since we already
#    2408         # pre-parsed the string as part of our And pre-parsing
# -> 2409         loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#    2410         errorStop = False
#    2411         for e in self.exprs[1:]:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in _parseCache(self, instring, loc, doActions, callPreParse)
#    1018         else:
#    1019             try:
# -> 1020                 value = self._parseNoCache( instring, loc, doActions, callPreParse )
#    1021                 ParserElement._exprArgCache[ lookup ] = (value[0],value[1].copy())
#    1022                 return value
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyparsing_py2.pyc in _parseNoCache(self, instring, loc, doActions, callPreParse)
#     987             else:
#     988                 for fn in self.parseAction:
# --> 989                     tokens = fn( instring, tokensStart, retTokens )
#     990                     if tokens is not None:
#     991                         retTokens = ParseResults( tokens,
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in non_math(self, s, loc, toks)
#    2418         #~ print "non_math", toks
#    2419         s = toks[0].replace(r'\$', '$')
# -> 2420         symbols = [Char(c, self.get_state()) for c in s]
#    2421         hlist = Hlist(symbols)
#    2422         # We're going into math now, so set font to 'it'
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in __init__(self, c, state)
#    1303         # The real width, height and depth will be set during the
#    1304         # pack phase, after we know the real fontsize
# -> 1305         self._update_metrics()
#    1306
#    1307     def __internal_repr__(self):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in _update_metrics(self)
#    1310     def _update_metrics(self):
#    1311         metrics = self._metrics = self.font_output.get_metrics(
# -> 1312             self.font, self.font_class, self.c, self.fontsize, self.dpi)
#    1313         if self.c == ' ':
#    1314             self.width = metrics.advance
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in get_metrics(self, font, font_class, sym, fontsize, dpi)
#     465             "height".
#     466         """
# --> 467         info = self._get_info(font, font_class, sym, fontsize, dpi)
#     468         return info.metrics
#     469
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in _get_info(self, fontname, font_class, sym, fontsize, dpi)
#     600
#     601         cached_font, num, symbol_name, fontsize, slanted = \
# --> 602             self._get_glyph(fontname, font_class, sym, fontsize)
#     603
#     604         font = cached_font.font
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/mathtext.pyc in _get_glyph(self, fontname, font_class, sym, fontsize)
#     714                 if gid is not None:
#     715                     symbol_name = cached_font.font.get_glyph_name(
# --> 716                         cached_font.charmap[num])
#     717
#     718         if symbol_name is None:
#
# RuntimeError: Face has no glyph names
